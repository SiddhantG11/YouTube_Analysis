# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import nltk
import ast
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

# %%
df = pd.read_csv('datasets/analysis.csv')

# %%
# no nul' values 
df.isna().sum()
# Out:
# title               0
# split_comments      0
# reordered_scores    0
# reordered_labels    0
# sentiment           0
# dtype: int64

# %%
df['reordered_scores'] = df['reordered_scores'].apply((lambda x: ast.literal_eval(x)))

# %%
fears = df.sort_values(by='reordered_scores', key=lambda x: x.apply(lambda y: y[0]), ascending=False)
frustrations = df.sort_values(by='reordered_scores', key=lambda x: x.apply(lambda y: y[1]), ascending=False)
aspirations = df.sort_values(by='reordered_scores', key=lambda x: x.apply(lambda y: y[2]), ascending=False)

# %%
fears
# Out:
#                                                 title  \
# 6233                      How to Beat Procrastination
# 5909                      How to Beat Procrastination
# 1383   5 Essential Tips for Long-Lasting Productivity
# 6558                      How to Beat Procrastination
# 7087          My Toxic Relationship With Productivity
# ...                                               ...
# 5623   How I Manage My Time - 10 Time Management Tips
# 14841       5 Small Changes to Supercharge Your Focus
# 1259   5 Essential Tips for Long-Lasting Productivity
# 11272       7 Actionable Ways to Achieve More in Life
# 5602   How I Manage My Time - 10 Time Management Tips
#
#                                                                            split_comments  \
# 6233                           "fear is the greatest illusion we create within our self."
# 5909                        i feel like i need to listen to this weekly to face my fears.
# 1383                                      али обдал чай кипятком :face_screaming_in_fear:
# 6558                                                 that fear compass concept is genius!
# 7087                                                     status anxiety - alain de botton
# ...                                                                                   ...
# 5623                                 i love this guy, the reason i started my dreams now.
# 14841                                                      thomas frank is an inspiration
# 1259                                                                      it's inspiring!
# 11272                                                               you're my inspiration
# 5602   drinking orange juice out of a fancy glass at home, that’s some goals right there.
#
#                                                          reordered_scores  \
# 6233    [0.9896448254585266, 0.006187118589878082, 0.0041680666618049145]
# 5909      [0.9816955924034119, 0.01092555746436119, 0.007378820795565844]
# 1383     [0.9796825647354126, 0.01780746690928936, 0.0025099022313952446]
# 6558    [0.9769877791404724, 0.0062966798432171345, 0.016715513542294502]
# 7087     [0.9682902693748474, 0.021380305290222168, 0.010329443961381912]
# ...                                                                   ...
# 5623    [0.0028450298123061657, 0.002766459947451949, 0.9943884611129761]
# 14841   [0.0027784034609794617, 0.002567431889474392, 0.9946541786193848]
# 1259    [0.002528827404603362, 0.0036696013994514942, 0.9938015937805176]
# 11272    [0.002028948161751032, 0.001852899556979537, 0.9961181282997131]
# 5602   [0.0010489796986803412, 0.0013131831074133515, 0.9976378083229065]
#
#                                reordered_labels sentiment
# 6233   ['fears', 'frustrations', 'aspirations']  negative
# 5909   ['fears', 'frustrations', 'aspirations']   neutral
# 1383   ['fears', 'frustrations', 'aspirations']  negative
# 6558   ['fears', 'frustrations', 'aspirations']  positive
# 7087   ['fears', 'frustrations', 'aspirations']   neutral
# ...                                         ...       ...
# 5623   ['fears', 'frustrations', 'aspirations']  positive
# 14841  ['fears', 'frustrations', 'aspirations']  positive
# 1259   ['fears', 'frustrations', 'aspirations']  positive
# 11272  ['fears', 'frustrations', 'aspirations']  positive
# 5602   ['fears', 'frustrations', 'aspirations']  positive
#
# [14926 rows x 5 columns]

# %% [markdown]
# # Clustering
# 1. I'll have to tokenize the data
# 2. Remove Stopwords
# 3. Stemming/Lemmatization [reduce words to their basic form] (running -> run)
# 4. vectorization
# 5. Possibly Feature Reduction

# %%
# Preprocess the text
def preprocess_text(text):
    text = re.sub(r'\W', ' ', str(text))
    text = text.lower()
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)
    text = re.sub(r'\^[a-zA-Z]\s+', ' ', text)
    text = re.sub(r'\s+', ' ', text, flags=re.I)
    text = re.sub(r'^b\s+', '', text)
    return text

# %%
df['processed_comments'] = df['split_comments'].apply(preprocess_text)

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_text(text):
    words = nltk.word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# %%
df['processed_comments'] = df['processed_comments'].apply(lemmatize_text)

# %%
# Vectorize the text
tfidf_vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'), max_features=1000)
X = tfidf_vectorizer.fit_transform(df['processed_comments'])

# %%
# Determine the optimal number of clusters using the elbow method
wcss = []
for i in range(1, 11):  # Try different numbers of clusters
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
# Plot the elbow curve
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
optimal_clusters = 4

# %%
# Cluster the data with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
clusters = kmeans.fit_predict(X)
# Out:
# /opt/anaconda3/envs/ai/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df['cluster'] = clusters

# %%
frustrations.head(20)
# Out:
#                                                               title  \
# 4713                 How I Manage My Time - 10 Time Management Tips
# 3002        How I Organize My Life - The "LAZI" Productivity System
# 5618                 How I Manage My Time - 10 Time Management Tips
# 3124                                My Complete Productivity System
# 3948                 How I Manage My Time - 10 Time Management Tips
# 6894                        My Toxic Relationship With Productivity
# 5086                 How I Manage My Time - 10 Time Management Tips
# 7455                        My Toxic Relationship With Productivity
# 7298                        My Toxic Relationship With Productivity
# 3530                                My Complete Productivity System
# 843                  How to Build Your Ultimate Productivity System
# 182                  How to Build Your Ultimate Productivity System
# 14492  Why You’re Always Distracted - 5 Mistakes Ruining Your Focus
# 9020            How to Organise your Life - Building a Second Brain
# 8123                        My Toxic Relationship With Productivity
# 8106                        My Toxic Relationship With Productivity
# 7413                        My Toxic Relationship With Productivity
# 11483          How to Be Effortlessly Disciplined: 5 Mindset Shifts
# 10172             The Most PRODUCTIVE Desk Setups on YouTube | 2021
# 3879                 How I Manage My Time - 10 Time Management Tips
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           how dare you leave a deck of cards outside of its box when not using it? and whats that card on the floor? as i love card magic myself, that hurts my feelings haha
# 3879                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      i totally feel the "when you're a productivity nerd and you're always unsatisfied at the end of the day" thing :grinning_face_with_sweat:
#
#                                                        reordered_scores  \
# 4713   [0.008109974674880505, 0.9773792028427124, 0.014510894194245338]
# 3002    [0.01956305094063282, 0.9771984219551086, 0.003238518023863435]
# 5618    [0.006598987150937319, 0.9766308665275574, 0.01677016355097294]
# 3124    [0.009665977209806442, 0.9747980833053589, 0.01553589478135109]
# 3948    [0.016225185245275497, 0.972160816192627, 0.011613949202001095]
# 6894   [0.018292831256985664, 0.9719666242599487, 0.009740522131323814]
# 5086    [0.01852129027247429, 0.9711097478866577, 0.010368946939706802]
# 7455    [0.01258024014532566, 0.9701489210128784, 0.017270857468247414]
# 7298    [0.019384639337658882, 0.9698436856269836, 0.01077162753790617]
# 3530   [0.022802716121077538, 0.9687666296958923, 0.008430668152868748]
# 843       [0.016361054033041, 0.9679449796676636, 0.015694020316004753]
# 182       [0.020506765693426132, 0.9672179818153381, 0.012275330722332]
# 14492  [0.019502565264701843, 0.9663799405097961, 0.014117542654275894]
# 9020   [0.020340245217084885, 0.9661168456077576, 0.013542860746383667]
# 8123    [0.01538755837827921, 0.9652299284934998, 0.019382519647479057]
# 8106   [0.014785315841436386, 0.9650924205780029, 0.020122261717915535]
# 7413    [0.016472378745675087, 0.9643732905387878, 0.01915430836379528]
# 11483  [0.012187200598418713, 0.9636662006378174, 0.024146588519215584]
# 10172    [0.01528489962220192, 0.962925136089325, 0.021789973601698875]
# 3879   [0.010904757305979729, 0.9615336060523987, 0.027561623603105545]
#
#                                reordered_labels sentiment
# 4713   ['fears', 'frustrations', 'aspirations']  positive
# 3002   ['fears', 'frustrations', 'aspirations']  negative
# 5618   ['fears', 'frustrations', 'aspirations']  negative
# 3124   ['fears', 'frustrations', 'aspirations']  negative
# 3948   ['fears', 'frustrations', 'aspirations']  negative
# 6894   ['fears', 'frustrations', 'aspirations']  negative
# 5086   ['fears', 'frustrations', 'aspirations']  negative
# 7455   ['fears', 'frustrations', 'aspirations']  negative
# 7298   ['fears', 'frustrations', 'aspirations']  positive
# 3530   ['fears', 'frustrations', 'aspirations']  negative
# 843    ['fears', 'frustrations', 'aspirations']  negative
# 182    ['fears', 'frustrations', 'aspirations']  negative
# 14492  ['fears', 'frustrations', 'aspirations']  negative
# 9020   ['fears', 'frustrations', 'aspirations']  negative
# 8123   ['fears', 'frustrations', 'aspirations']   neutral
# 8106   ['fears', 'frustrations', 'aspirations']  positive
# 7413   ['fears', 'frustrations', 'aspirations']  negative
# 11483  ['fears', 'frustrations', 'aspirations']  negative
# 10172  ['fears', 'frustrations', 'aspirations']  negative
# 3879   ['fears', 'frustrations', 'aspirations']  negative

# %% [markdown]
# # Insights From Frustrations
